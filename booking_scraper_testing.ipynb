# %%
from booking_tools import Booker
import asyncio
import time

# %%
booker = Booker(location='Milan', from_='2025-07-20', to_='2025-08-01', adults=2, children=0,
               rooms=1, sort='Price', holiday_length=4, airport_from='London',
               airport_to='Milan Malpensa', review_score=8, mealplan='Breakfast', twin_beds='Twin Beds',
               stars=4, distance='1 Mile')

# %%
booker = Booker(location='Antalya', from_='2025-06-11', to_='2025-07-11', adults=2, children=0,
               rooms=1, sort='Price', holiday_length=7)

# %%
start_time = time.time()
hotels_flights_df = asyncio.run(booker.booking_search())
end_time = time.time()

print('Execution Time: '+ str(round(end_time - start_time)) + 's')
# Out:
# Execution Time: 59s

# %%
hotels_flights_df
# Out:
#                              name                  location airport_from  \
# 178                 Hotel Crivi's  Milan City Centre, Milan       London
# 109      Jr Hotels Bocconi Milano  Milan City Centre, Milan       London
# 85       Jr Hotels Bocconi Milano  Milan City Centre, Milan       London
# 41       Jr Hotels Bocconi Milano  Milan City Centre, Milan       London
# 110                 Hotel Crivi's  Milan City Centre, Milan       London
# ..                            ...                       ...          ...
# 84   Petit Palais Hotel De Charme  Milan City Centre, Milan       London
# 199  Petit Palais Hotel De Charme  Milan City Centre, Milan       London
# 108    BB Hotels Smarthotel Duomo  Milan City Centre, Milan       London
# 153  Petit Palais Hotel De Charme  Milan City Centre, Milan       London
# 177  Petit Palais Hotel De Charme  Milan City Centre, Milan       London
#
#                                airport_to      depart      return  rating  \
# ...

# %%
start_time = time.time()
flights_df = asyncio.run(booker.kayak_flights_search())
end_time = time.time()

print('Execution Time: '+ str(round(end_time - start_time)) + 's')
# Out:
# Execution Time: 16s

# %%
flights_df
# Out:
#    airport_from                            airport_to   date_from     date_to  \
# 1        London  Milan Malpensa International Airport  2025-07-20  2025-07-24
# 2        London  Milan Malpensa International Airport  2025-07-21  2025-07-25
# 5        London  Milan Malpensa International Airport  2025-07-24  2025-07-28
# 3        London  Milan Malpensa International Airport  2025-07-22  2025-07-26
# 6        London  Milan Malpensa International Airport  2025-07-25  2025-07-29
# 4        London  Milan Malpensa International Airport  2025-07-23  2025-07-27
# 9        London  Milan Malpensa International Airport  2025-07-28  2025-08-01
# 10       London  Milan Malpensa International Airport  2025-07-29  2025-08-02
# 0        London  Milan Malpensa International Airport  2025-07-19  2025-07-23
# 7        London  Milan Malpensa International Airport  2025-07-26  2025-07-30
# 8        London  Milan Malpensa International Airport  2025-07-27  2025-07-31
#
# ...

# %%
booker.airport_from = False
booker.airport_to = False

# %%
start_time = time.time()
hotels_df = asyncio.run(booker.booking_search())
end_time = time.time()

print('Execution Time: '+ str(round(end_time - start_time)) + 's')
# Out:
# Execution Time: 12s

# %%
hotels_df
# Out:
#                             name                  location checkin_date  \
# 0       Jr Hotels Bocconi Milano  Milan City Centre, Milan   2025-07-26
# 0       Jr Hotels Bocconi Milano  Milan City Centre, Milan   2025-07-24
# 0                  Hotel Crivi's  Milan City Centre, Milan   2025-07-28
# 0       Jr Hotels Bocconi Milano  Milan City Centre, Milan   2025-07-25
# 1                  Hotel Crivi's  Milan City Centre, Milan   2025-07-26
# ..                           ...                       ...          ...
# 21  Petit Palais Hotel De Charme  Milan City Centre, Milan   2025-07-25
# 22  Petit Palais Hotel De Charme  Milan City Centre, Milan   2025-07-23
# 23  Petit Palais Hotel De Charme  Milan City Centre, Milan   2025-07-27
# 22  Petit Palais Hotel De Charme  Milan City Centre, Milan   2025-07-26
# 23    BB Hotels Smarthotel Duomo  Milan City Centre, Milan   2025-07-24
#
#    checkout_date  total_price  rating  reviews  \
# 0     2025-07-30          488     8.2      118
# ...
